# %%
import pandas
import csv

# %%
csvfile = pandas.read_csv('../mean_food_insecurity.csv', encoding='utf-8')

# %%
csvfile
# Out:
#    State  FOODINSEC_10_12  FOODINSEC_13_15  CH_FOODINSEC_12_15  \
# 0     AK             12.1             13.3                 1.2
# 1     AL             17.9             17.6                -0.3
# 2     AR             14.9             14.9                 0.0
# 3     AZ             19.7             19.2                -0.5
# 4     CA             15.6             12.6                -3.0
# 5     CO             14.1             12.1                -2.0
# 6     CT             13.4             13.1                -0.3
# 7     DC             11.6             11.9                 0.3
# 8     DE             12.0             13.2                 1.2
# 9     FL             14.8             12.7                -2.1
# 10    GA             16.9             14.9                -2.0
# 11    HI             14.0              9.7                -4.3
# 12    IA             13.5             14.8                 1.3
# 13    ID             12.6             10.6                -2.0
# ...

# %%
with open('temp.json', 'w') as f:
    f.write(csvfile.to_json(orient='records', lines=True))
