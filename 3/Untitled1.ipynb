# %%
import pandas
import csv

# %%
csvfile = pandas.read_csv('../FID.csv', encoding='utf-8')

# %%
csvfile
# Out:
#                     name  population Food_insecurity_rate1  \
# 0                Alabama   4,863,300                16.50%
# 1                 Alaska     741,894                13.40%
# 2                Arizona   6,931,071                14.90%
# 3               Arkansas   2,988,248                17.20%
# 4             California  39,250,017                11.70%
# 5               Colorado   5,540,545                11.30%
# 6            Connecticut   3,576,452                11.60%
# 7               Delaware     952,065                12.00%
# 8   District of Columbia     681,170                12.40%
# 9                Florida  20,612,439                13.90%
# 10               Georgia  10,310,371                15.10%
# 11                Hawaii   1,428,557                11.80%
# 12                 Idaho   1,683,140                13.20%
# 13              Illinois  12,801,539                11.00%
# 14               Indiana   6,633,053                13.70%
# ...

# %%
with open('temp.json', 'w') as f:
    f.write(csvfile.to_json(orient='records', lines=True))
